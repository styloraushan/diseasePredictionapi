# %%
# import pandas as pd

# Load your dataset
df = pd.read_csv("Dataset/diseasesymp_updated.csv", encoding="latin1")

# Show the last few rows
df.tail()

# import pandas as pd
# import joblib

# # Check dataset
# df = pd.read_csv("Dataset/diseasesymp_updated.csv", encoding="latin1")
# print(df.tail())

# # Check retrained model
# model = joblib.load("model.pkl")
# encoder = joblib.load("label_encoder.pkl")

# print("Model retrained with", len(df), "rows")
# print("Known diseases:", list(encoder.classes_)[-10:])
# Out:
#       itching  skin_rash  nodal_skin_eruptions  continuous_sneezing  \
# 5308        0          0                     0                    0
# 5309        0          0                     0                    0
# 5310        0          0                     0                    0
# 5311        0          0                     0                    0
# 5312        1          0                     0                    0
#
#       shivering  chills  joint_pain  stomach_pain  acidity  ulcers_on_tongue  \
# 5308          0       0           0             0        0                 0
# 5309          0       0           0             0        0                 0
# 5310          0       0           0             0        0                 0
# 5311          0       0           0             0        0                 0
# 5312          0       0           0             0        0                 0
#
#       ...  eye_redness  morning_stiffness  joint_swelling  cold_intolerance  \
# ...
